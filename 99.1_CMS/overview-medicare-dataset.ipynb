# %% [markdown]
# # Objective
#
# The objective of this notebook is to explore the CMS (Medicare and Medicaid) dataset. At this moment, there is no specific interest in any particular question.

# %% [markdown]
# **Necessary Imports**

# %%
## import libs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


'''
Settings for dpi, color palette, and background
for seaborn
'''
palette = [
    
    "#667307",  
    "#BF571B",  
    "#C1D911",  
    "#F2B84B",  
    "#ABBF0F",  
    "#5679BF", "#5679BF", "#5679BF"  
]


sns.set_style('whitegrid')
sns.set_palette("coolwarm")
plt.rcParams['figure.figsize'] = 12, 4
plt.rcParams['figure.dpi'] = 110
plt.rcParams['font.size'] = 10 

## Configuration to display all columns of the dataframe
pd.set_option('display.max_columns', None)

path = '/kaggle/input/medicare-and-medicaid/CMS.csv' ## file path
cms_data = pd.read_csv(path)

# %% [markdown]
# **Searching for inconsistencies**

# %%
cms_data.sample(5)
# Out:
#        RowId  YearStart LocationAbbr   LocationDesc DataSource  PriorityArea1  \
# 17306    NaN       2020           AR        Arizona   Medicare            NaN
# 28429    NaN       2017           NV         Nevada   Medicare            NaN
# 17659    NaN       2018           MA  Massachusetts   Medicare            NaN
# 20935    NaN       2021           AL        Alabama   Medicare            NaN
# 11221    NaN       2020           PA   Pennsylvania   Medicare            NaN
#
#        PriorityArea2  PriorityArea3  PriorityArea4                    Class  \
# 17306            NaN            NaN            NaN  Cardiovascular Diseases
# 28429            NaN            NaN            NaN  Cardiovascular Diseases
# 17659            NaN            NaN            NaN  Cardiovascular Diseases
# 20935            NaN            NaN            NaN  Cardiovascular Diseases
# 11221            NaN            NaN            NaN  Cardiovascular Diseases
#
#                                             Topic  \
# 17306                      Coronary Heart Disease
# 28429                                      Stroke
# 17659  Acute Myocardial Infarction (Heart Attack)
# 20935  Acute Myocardial Infarction (Heart Attack)
# 11221                Major Cardiovascular Disease
#
#                                                 Question Data_Value_Type  \
# 17306  Prevalence of in-hospital mortality among coro...           Crude
# 28429  Cerebrovascular disease (stroke) hospitalizati...           Crude
# 17659  Acute myocardial infarction (heart attack) hos...           Crude
# 20935  Acute myocardial infarction (heart attack) hos...           Crude
# 11221  Major cardiovascular disease hospitalization r...           Crude
#
#         Data_Value_Unit  Data_Value  Data_Value_Alt  \
# 17306       Percent (%)         6.3             6.3
# 28429  Rate per 100,000       935.2           935.2
# 17659  Rate per 100,000       862.9           862.9
# 20935  Rate per 100,000       494.2           494.2
# 11221  Rate per 100,000      2949.0          2949.0
#
#        Data_Value_Footnote_Symbol  Data_Value_Footnote  Low_Confidence_Limit  \
# 17306                         NaN                  NaN                   5.2
# 28429                         NaN                  NaN                 878.0
# 17659                         NaN                  NaN                 664.0
# 20935                         NaN                  NaN                 311.4
# 11221                         NaN                  NaN                2648.3
#
#        High_Confidence_Limit Break_Out_Category           Break_Out ClassId  \
# 17306                    7.7             Gender              Female      C1
# 28429                  996.0             Gender                Male      C1
# 17659                 1121.2               Race            Hispanic      C1
# 20935                  784.4               Race             Unknown      C1
# 11221                 3283.9               Race  Non-Hispanic Asian      C1
#
#       TopicId QuestionId Data_Value_TypeID BreakOutCategoryId BreakOutId  \
# 17306      T4      MD303             Crude              BOC02      GEN02
# 28429      T6      MD601             Crude              BOC02      GEN01
# 17659      T3      MD401             Crude              BOC04      RAC04
# 20935      T3      MD401             Crude              BOC04      RAC08
# 11221      T1      MD101             Crude              BOC04      RAC03
#
#        LocationId                       GeoLocation
# 17306           4  POINT (-111.7638113 34.86597028)
# 28429          32  POINT (-117.0718406 39.49324039)
# 17659          25  POINT (-72.08269067 42.27687047)
# 20935           1  POINT (-86.63186076 32.84057112)
# 11221          42  POINT (-77.86070029 40.79373015)

# %% [markdown]
# **missing Values**

# %%
'''
This function takes the dataframe as input and returns another 
dataframe where the total percentage of missing values is shown 
for each column along with their respective data types.
'''

def display_missing_data(data):
    total = data.isnull().sum()
    percent = np.round(total / len(data) * 100, 2)
    df_null = pd.concat([total, percent], axis=1, keys=['Qtd. Nulos', 'Percent'])
    types = []
    
    for col in data.columns:
        dtypes = str(data[col].dtype)
        types.append(dtypes)
    
    df_null['Types'] = types
    return ((np.round(df_null.T, 2)).transpose())


## uso da função
display_missing_data(cms_data)
# Out:
#                            Qtd. Nulos Percent    Types
# RowId                           33454   100.0  float64
# YearStart                           0     0.0    int64
# LocationAbbr                        0     0.0   object
# LocationDesc                        0     0.0   object
# DataSource                          0     0.0   object
# PriorityArea1                   33454   100.0  float64
# PriorityArea2                   33454   100.0  float64
# PriorityArea3                   33454   100.0  float64
# PriorityArea4                   33454   100.0  float64
# Class                               0     0.0   object
# Topic                               0     0.0   object
# Question                            0     0.0   object
# Data_Value_Type                     0     0.0   object
# Data_Value_Unit                     0     0.0   object
# Data_Value                          0     0.0  float64
# Data_Value_Alt                      0     0.0  float64
# Data_Value_Footnote_Symbol      33454   100.0  float64
# Data_Value_Footnote             33454   100.0  float64
# Low_Confidence_Limit                0     0.0  float64
# High_Confidence_Limit               0     0.0  float64
# Break_Out_Category                  0     0.0   object
# Break_Out                           0     0.0   object
# ClassId                             0     0.0   object
# TopicId                             0     0.0   object
# QuestionId                          0     0.0   object
# Data_Value_TypeID                   0     0.0   object
# BreakOutCategoryId                  0     0.0   object
# BreakOutId                          0     0.0   object
# LocationId                          0     0.0    int64
# GeoLocation                       720    2.15   object

# %% [markdown]
# > There are excessive null values to the point where it is not plausible to recover the values. In some cases, it is 100%.

# %%
## Delete columns containing null values
cms_data = (cms_data.dropna(axis=1))

# %% [markdown]
# > In the process, we lost the '**GeoLocation**' column. We can evaluate the possibility of treating the data in order to extract **longitude** and **latitude**.

# %%
'''
This function creates a dataframe based on the received dataframe. 
It returns another dataframe containing the following information:

- Most frequent values
- Number of values (size of items in the column)
- Percentage of frequency of the most common item
'''
def most_frequent_values(data):
    total = data.count()
    df_mfq = pd.DataFrame(total)
    df_mfq.columns = ['Total']
    
    items = []
    vals = []
    
    for col in data.columns:
        try:
            itm = data[col].value_counts().index[0]
            val = data[col].value_counts().values[0]
            
            items.append(itm)
            vals.append(val)
            
        except Exception as ex:
            print(ex)
            items.append(0)
            vals.append(0)
            continue

    # Moving this block outside the loop
    df_mfq['Most frequent item'] = items
    df_mfq['Frequence'] = vals
    df_mfq['Percent from total'] = np.round(vals / total * 100, 3)
    
    return df_mfq

## how to use the function
most_frequent_values(cms_data)
# Out:
#                        Total  \
# YearStart              33454
# LocationAbbr           33454
# LocationDesc           33454
# DataSource             33454
# Class                  33454
# Topic                  33454
# Question               33454
# Data_Value_Type        33454
# Data_Value_Unit        33454
# Data_Value             33454
# Data_Value_Alt         33454
# Low_Confidence_Limit   33454
# High_Confidence_Limit  33454
# Break_Out_Category     33454
# Break_Out              33454
# ClassId                33454
# TopicId                33454
# QuestionId             33454
# Data_Value_TypeID      33454
# BreakOutCategoryId     33454
# BreakOutId             33454
# LocationId             33454
#
#                                                       Most frequent item  \
# YearStart                                                           2016
# LocationAbbr                                                          AR
# LocationDesc                                               United States
# DataSource                                                      Medicare
# Class                                            Cardiovascular Diseases
# Topic                                       Major Cardiovascular Disease
# Question               Major cardiovascular disease hospitalization r...
# Data_Value_Type                                                    Crude
# Data_Value_Unit                                         Rate per 100,000
# Data_Value                                                           0.0
# Data_Value_Alt                                                       0.0
# Low_Confidence_Limit                                                -1.0
# High_Confidence_Limit                                               -1.0
# Break_Out_Category                                                  Race
# Break_Out                                                           Male
# ClassId                                                               C1
# TopicId                                                               T1
# QuestionId                                                         MD101
# Data_Value_TypeID                                                  Crude
# BreakOutCategoryId                                                 BOC04
# BreakOutId                                                         GEN01
# LocationId                                                            59
#
#                        Frequence  Percent from total
# YearStart                   5609              16.766
# LocationAbbr                1281               3.829
# LocationDesc                 720               2.152
# DataSource                 33454             100.000
# Class                      33454             100.000
# Topic                       5626              16.817
# Question                    2814               8.412
# Data_Value_Type            33454             100.000
# Data_Value_Unit            16884              50.469
# Data_Value                  2833               8.468
# Data_Value_Alt              2833               8.468
# Low_Confidence_Limit        2184               6.528
# High_Confidence_Limit       2184               6.528
# Break_Out_Category         22150              66.210
# Break_Out                   3744              11.191
# ClassId                    33454             100.000
# TopicId                     5626              16.817
# QuestionId                  2814               8.412
# Data_Value_TypeID          33454             100.000
# BreakOutCategoryId         22150              66.210
# BreakOutId                  3744              11.191
# LocationId                   720               2.152

# %%
'''
This function creates a dataframe based on the received dataframe to display the data 
types for each column and how many unique values each column has.
'''

def display_unique_values(data):
    unique_values = data.nunique()
    df_unique = pd.DataFrame({'Unique Values': unique_values})
    
    types = []
    for col in data.columns:
        dtypes = str(data[col].dtype)
        types.append(dtypes)
    
    df_unique['Types'] = types
    return df_unique

## How to use the function
display_unique_values(cms_data)
# Out:
#                        Unique Values    Types
# YearStart                          6    int64
# LocationAbbr                      51   object
# LocationDesc                      52   object
# DataSource                         1   object
# Class                              1   object
# Topic                              6   object
# Question                          12   object
# Data_Value_Type                    1   object
# Data_Value_Unit                    2   object
# Data_Value                     12699  float64
# Data_Value_Alt                 12698  float64
# Low_Confidence_Limit           12440  float64
# High_Confidence_Limit          13465  float64
# Break_Out_Category                 4   object
# Break_Out                         10   object
# ClassId                            1   object
# TopicId                            6   object
# QuestionId                        12   object
# Data_Value_TypeID                  1   object
# BreakOutCategoryId                 4   object
# BreakOutId                        10   object
# LocationId                        52    int64

# %% [markdown]
# **visualize**

# %% [markdown]
# > In this step, we will quickly look especially at the categorical columns, using simple plots. For example, for now, let's exclude the need to see the "Questions" column as it requires something more sophisticated and intricate.

# %%
sns.countplot(data=cms_data, y='Topic');

# %%
sns.countplot(data=cms_data, y='YearStart');

# %%
sns.countplot(data=cms_data, y='Break_Out', palette='coolwarm');

# %%
sns.countplot(data=cms_data, y='Break_Out_Category');
