# %%
import pandas as pd
import numpy as np
nsmes_df = pd.read_csv('NSMES1988.csv')
nsmes_df
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0              1       5        0        0         0          0         1
# 1              2       1        0        2         0          2         0
# 2              3      13        0        0         0          3         3
# 3              4      16        0        5         0          1         1
# 4              5       3        0        0         0          0         0
# ...          ...     ...      ...      ...       ...        ...       ...
# 4401        4402      11        0        0         0          0         0
# 4402        4403      12        0        0         0          0         0
# 4403        4404      10        0       20         0          1         1
# 4404        4405      16        1        0         0          0         0
# 4405        4406       0        0        0         0          0         0
#
#          health  chronic      adl region  age  gender married  school  \
# ...

# %%
#checking the structural information of the data
#nsmes_df.info()
#nsmes_df.drop('Unnamed: 0', axis=1, inplace=True)# removed 'Unnamed: 0' which is not significant
nsmes_df
#Finding out if there are null values and non null values count
nsmes_df

null_counts = nsmes_df.isnull().sum()
print(null_counts.dtype) #There are no null values
print(null_counts)
# Out:
# int64
# visits       0
# nvisits      0
# ovisits      0
# novisits     0
# emergency    0
# hospital     0
# health       0
# chronic      0
# adl          0
# region       0
# age          0
# gender       0
# married      0
# school       0
# income       0
# employed     0
# insurance    0
# medicaid     0
# dtype: int64

# %%
#adding columns - salary*10000 and age*10

nsmes_df['act_age'] = nsmes_df['age']*10
nsmes_df['act_income'] = nsmes_df['income']*10000
nsmes_df

#nsmes_df['visits'].max()
#nsmes_df['ovisits'].max()
#nsmes_df['novisits'].max()
#nsmes_df['emergency'].max()
#nsmes_df['hospital'].max()
#nsmes_df['nvisits'].max()

#All these values are smaller hence we can save memory if we use unit8 instead of default int64 datatype
# Out:
# 104

# %%
#Checking if there are any duplicate rows

duplicate_rows = nsmes_df.duplicated().value_counts()
duplicate_rows

#There are no duplicate rows present
# Out:
# False    4406
# Name: count, dtype: int64

# %%
#Trying to analyze categorical values
nsmes_df['health'].unique()
nsmes_df['health'].value_counts()

nsmes_df['adl'].unique()
nsmes_df['adl'].value_counts()

nsmes_df['gender'].unique()
nsmes_df['gender'].value_counts()

nsmes_df['employed'].unique()
nsmes_df['employed'].value_counts()

nsmes_df['medicaid'].unique()
nsmes_df['medicaid'].value_counts()

nsmes_df['insurance'].unique()
nsmes_df['insurance'].value_counts()
# Out:
# insurance
# yes    3421
# no      985
# Name: count, dtype: int64

# %%
#Exporting data to new csv file
nsmes_df.to_csv('NSMES1988_new.csv', index=False)

# %% [markdown]
# # **Visual Observations of the data**
#
# **About the data set:** This is Patient's dataset about their visits to pysicians and hospital and information about their insurance and other paramters
#
# **Size of the data:** 4406 * 19 columns
#
# **Observations:**
#
# 1.   One of the columns named "Unnamed: 0" which was kind
# of index and there was no other significance of it hence I dropped it.
# 2.   There are columns which count the patient's visits to hospital or pysician. I checked max values and found that they are very small and we do not need to use default data type "int64". Instead we can use unit8.
#
#
# 1.   There are no null values in data set. All the rows have all the data elements populated.
# 2.   Added 2 more columns as act_salary and act_age as they were divided by 10000 and 10 respectivly.
#
#
# 1.   Checked all the categorical values(all the columns in the dataset and found that they are clean in consitent)
