# %% [markdown]
# # <b>Probability Distribution</b>

# %% [markdown]
# ## <b> Agenda </b>

# %% [markdown]
# * Probability and Its Importance
# * Random Variable
# * Probability Distribution
#     * Discrete Probability Distribution
#     * Continuous Probability Distribution
# * Discrete Probability Distribution
#     * Bernoulli Distribution
#     * Binomial Distribution
#     * Poisson Distribution
# * Continuous Probability Distribution
#     * Normal Distribution
#     * Uniform Distribution
# * Probability Density Function and Mass Function
# * Cumulative Distribution Function
# * Central Limit Theorem
# * Bayes’ Theorem
# * Estimation Theory

# %% [markdown]
# ## __1. Probability and Its Importance__

# %% [markdown]
# Probability is a mathematical term for the likelihood of an event happening.
#
# ![proba.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/proba.PNG)

# %% [markdown]
# The chance of any event occurring is a number between 0 and 1.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mathematically, the probability is defined as the ratio of favorable cases to the total number of cases.
#
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Updated_Images/Lesson_7/7_01/Lesson_07_Probability_distributionMathematically_the_probability.png)

# %% [markdown]
# ### __1.1 Importance of Probability__

# %% [markdown]
# - It is used to anticipate risks and identify ways to manage such risks.
#
# - It is used to make predictions about future events based on their likelihood.
#
# - It is a powerful tool used to incorporate uncertainty in planning and decision-making.

# %% [markdown]
# ### __1.2 Real-Life Examples__

# %% [markdown]
# - __Flipping of a Coin:__  Possession and starting direction are determined at the beginning of a football game using a coin toss.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# The probability of getting the desired outcome while flipping a coin is 0.5 or 50%.

# %% [markdown]
# - <b> Election Forecasts: </b>
# Many political analysts use the results of exit polls to predict whether a certain political party will come into power.
#
# ![election.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/election.PNG)

# %% [markdown]
# **Experiment** : process with uncertain outcome (coin flip, customer purchase)
# **Sample Space** : all possible outcomes
# **Event** : a condition defining a set of outsomes that we care about (e.g. "Spent > $100")
# **Outcome** : a single result (heads, tails, purchased, not purchased)

# %% [markdown]
# ## __2. Random Variable__
#
# - It is a type of variable whose value depends on the numerical outcomes of certain random events.
# - These variables take on specific values that are determined by the outcomes of random events.
# - These variables must be quantifiable and often take the form of real numbers.
#
# **Example:** Assume X is the outcome of rolling three dice
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Example_Assume_X.png)

# %% [markdown]
# ### __2.1 Types of Random Variables__
#
#
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Types_of_Random_Variables.png)
#
#
#
# __Discrete random variables: Examples__
# - Number of misprints on a page
# - Number of customers at a theater
# - Number of cars at a gas station
# - Outcome of throwing a dice
#
# **Note:** These random variables take only selected values in a range, like whole numbers.
#
# **Continuous random variables: Examples**
# - Temperature
# - Length
# - Height
# - Time
#
# **Note:** These random variables can take any value in a certain range.

# %% [markdown]
# ## __3. Probability Distribution__

# %% [markdown]
# A probability distribution is a statistical function that describes the range of possible values and their associated probabilities for a random variable.
#
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Updated_Images/Lesson_7/7_01/Lesson_07_Probability_distributionProbability_Distribution_1.png)

# %% [markdown]
# Probability distributions can be visualized using:
#
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Probability_distributions_can_be_visualized.png)

# %% [markdown]
# **Example 1:** Consider a production process that produces both non-defective and potentially defective pieces. After inspecting a large number of pieces, the following probabilities were determined:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Example_1.png)
#
#
# - Analyzing this probability distribution helps assess the distribution of defective and non-defective pieces in production, aiding in quality control evaluation, product acceptance decisions, and estimation of rework or reject rates.

# %% [markdown]
# **Example 2:** Consider the outcome of throwing a fair dice. Its probability distribution is:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Example_2.png)
#
#
# ### __3.1 Expected Value E(x)__
#
# The expected value of a random variable is obtained by multiplying each possible value of the variable by its corresponding probability, and then adding these products.
#
#
# Calculating the expected value for a random variable x that represents the outcome of throwing a dice:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/3_1_Expected_Value_Ex.png)

# %% [markdown]
# ## __4. Discrete Probability Distribution__
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/4_Discrete_Probability_Distribution.png)
#
#
#
#
# **Note:** Binomial distribution and the poisson distribution are based on the principle of Bernoulli trials or processes.

# %% [markdown]
# ## __5. Bernoulli Distribution__
#
# The Bernoulli distribution is a discrete probability distribution that models a single trial with two possible outcomes, typically labeled as success (denoted as 1) and failure (denoted as 0).
#
# It is a discrete probability distribution which takes up only two distinct values: 1 and 0
#
# - 1 indicates success
#
# - 0 indicates failure
#
#
# <b>Example 1:</b>
#
# - A coin toss is a variable that follows Bernoulli distribution. It can be head or tail.
# - A head or a tail indicates success or failure. As a result, both these probabilities range from 0 to 1.
#
# ![cointoss.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/cointoss.PNG)

# %% [markdown]
# - A probability mass function (PMF) is a mathematical function that calculates the probability of the possible values for a discrete random variable.
#
# The PMF of a Bernoulli distribution is given by:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/The_PMF.png)
#
#
# - x represents the outcome, which can be a success (x=1) or failure (x=0).
# - p denotes the probability of success.
# - q equals 1-p and represents the probability of failure.
# - The value of p lies between 0 and 1 (0 < p < 1).
#
# Let's see how to find cumulative distribution function, mean, and variance
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Let_s_see_how.png)

# %% [markdown]
# **Example 2:** When a dice is rolled, what is the probability of getting 1?
#
# ![exampledice.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/exampledice.PNG)
#
# In this example, getting 1 is success and all other outcomes are failure.
#
# The probability of getting 1 is ⅙. So, p=⅙
#
# Probability of failure q=⅚, and
#
# Variance is pq = ⅙* ⅚ = 5/36

# %% [markdown]
# **Note:** We will import `scipy.stats` module from SciPy library which contains a large number of probability distributions as well as statistical functions.

# %% [markdown]
# ### __Python Code to Plot the Curve for a Bernoulli  Distribution__

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import bernoulli, gaussian_kde

# Bernoulli distribution parameters
p = 0.6  # Probability of success

# Generating Bernoulli distribution data
data_bernoulli = bernoulli.rvs(p, size=1000)

# Plot histogram
plt.hist(data_bernoulli, bins=np.arange(-0.5, 2, 1), density=True, alpha=0.5, color='pink', edgecolor='black', linewidth=2, align='mid')

# Calculate the KDE
kde = gaussian_kde(data_bernoulli)
kde_xs = np.linspace(-1, 2, 300)
kde_ys = kde.pdf(kde_xs)

# Plot KDE
plt.plot(kde_xs, kde_ys, color='red')

# Add labels
plt.xlabel('Bernoulli')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# ## __6. Binomial Distribution__

# %% [markdown]
# A binomial distribution indicates the probability of a SUCCESS or FAILURE of a survey that is repeated multiple times. The binomial is a type of distribution that has two possible outcomes.
#
# The binomial distribution formula is for any random variable x, given by:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/The_binomial_distribution.png)

# %% [markdown]
# If p is the probability of occurrence in a trial, the probability of non-occurrence is q= 1-p, which is also a constant.
# So, when X follows the binomial with parameters n and p, X can take values 0, 1....r...n.
#
#
# ![image.png](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/If_p_is_the_probability.png)
#
#
# This follows multiplication theorem of probability.

# %% [markdown]
# #### <b> Example to Illustrate a Real-World Problem of a Spare Parts Manufacturer:</b>
#
# If the probability of a machine producing a defective piece is 0.05, what is the probability of finding an inspection sample of size n that has four or more defectives?
#
# <b>Solution</b>: Let X denote the random variable indicating the number of defectives in the inspection sample of size 10.
#
# Assuming that the process is Bernoulli, X follows a binomial with parameters n= 10 and p = 0.05
#
# ![binomialexample.PNG](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/binomialexample.jpg)
#
# First, calculate
# 𝑃
# (
# 𝑋
# ≤
# 3
# )
# P(X≤3):
# We calculate the probabilities for
# 𝑋
# =
# 0
# ,
# 1
# ,
# 2
# ,
# 3
# X=0,1,2,3 and sum them up:

# %% [markdown]
# | X   | P(X)   |
# | --- | ------ |
# | 0   | 0.5987 |
# | 1   | 0.3151 |
# | 2   | 0.0746 |
# | 3   | 0.0105 |
# | **Total** | **0.9989** |

# %% [markdown]
# Summing up these probabilities:
#
#
#
#
# P(X≤3)=P(X=0)+P(X=1)+P(X=2)+P(X=3)
# 𝑃
# (
# 𝑋
# ≤
# 3
# )
# =
# 0.5987
# +
# 0.3151
# +
# 0.0746
# +
# 0.0105
# =
# 0.9989
#
#
#
# <b> P(X ≥ 4) = 1 </b> The probability that the inspection sample has three or fewer defectives is equal to the probability that X is less than or equal to 3.
#
# <b> Now, find
#
# P(X≥4):
# 𝑃
# (
# 𝑋
# ≥
# 4
# )
# =
# 1
# −
# 𝑃
# (
# 𝑋
# ≤
# 3
# )
# =
# 1
# −
# 0.9989
# =
# 0.0011
# P(X≥4)=1−P(X≤3)=1−0.9989=0.0011
#
# <b>Note:</b> The result justifies the assumption that the process is Bernoulli.

# %% [markdown]
# ### __Python Code to Plot the Curve for a Binomial Distribution__

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binom, gaussian_kde

# Parameters for the binomial distribution
n, p = 20, 0.8  # number of trials, probability of success per trial

# Generate binomially distributed data
data_binom = binom.rvs(n, p, size=10000)

# Plot histogram
plt.hist(data_binom, bins=range(n+2), density=True, alpha=0.5, color='green')

# Calculate the KDE
kde = gaussian_kde(data_binom)
kde_xs = np.linspace(data_binom.min(), data_binom.max(), 301)
kde_ys = kde.pdf(kde_xs)

# Plot KDE
plt.plot(kde_xs, kde_ys, color='blue')

# Add labels
plt.xlabel('Binomial')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# ### __Use Case: Determine the Probability of r Successes__

# %% [markdown]
# #### __Problem Statement:__

# %% [markdown]
# Consider a random experiment of tossing a biased coin 6 times where the probability of getting a head is 0.6. If ‘getting
# a head’ is considered as ‘success’, then the binomial distribution table will contain the probability of r successes
# for each possible value of r.

# %% [markdown]
# ![binomialexampletable.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probability/binomialexampletable.PNG)

# %% [markdown]
#  Calculate a binomial distribution using the values of n and p to check if the distribution is normal.

# %% [markdown]
# **Solution:**

# %% [markdown]
# This distribution has a mean equal to np and variance of np(1-p).
#
# Here, scipy.stats module contains various functions for statistical calculations and tests. The stats() function of
# the scipy.stats.binom module can be used to calculate a binomial distribution using the values of n and p.

# %%
from scipy.stats import binom
# Setting the values of n and p
n = 6
p = 0.6
# Defining the list of r values
r_values = list(range(n + 1))
# Obtaining the mean and variance
mean, var = binom.stats(n, p)
# List of pmf values
dist = [binom.pmf(r, n, p) for r in r_values ]
# Printing the table
print("r\tp(r)")
for i in range(n + 1):
    print(str(r_values[i]) + "\t" + str(dist[i]))
# Printing mean and variance
print("mean = "+str(mean))
print("variance = "+str(var))
# Out:
# r	p(r)
# 0	0.004096000000000003
# 1	0.03686400000000002
# 2	0.1382400000000001
# 3	0.2764800000000001
# 4	0.3110400000000001
# 5	0.1866240000000001
# 6	0.04665599999999999
# mean = 3.5999999999999996
# variance = 1.44

# %% [markdown]
# The scipy.stats.binom.pmf function is used to obtain the probability mass function for a certain value of r, n, and p.
# We can obtain the distribution by passing all possible values of r(0 to n).

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
# Setting the values of n and p
n = 6
p = 0.6
# Defining the list of r values
r_values = list(range(n + 1))
# List of pmf values
dist = [binom.pmf(r, n, p) for r in r_values ]
# Plotting the graph
plt.bar(r_values, dist)
plt.show()

# %% [markdown]
# As we can see, the distribution is normal.

# %% [markdown]
# ## __7. Poisson Distribution__

# %% [markdown]
# Poisson distribution measures the probability of an event occurring over a specified period. It has only one parameter, lambda (λ), which is the mean number of events.
#
#
#
# If X denotes the random variable indicating the number of occurrences which follows a Poisson distribution, the
# probabilities of X taking a given value (0, 1, 2 .....) depends on its expected value λ. λ is the parameter
# of the distribution.
#
# ![poisson.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/poisson.PNG)

# %% [markdown]
# <b> When X follows a Poisson distribution with parameter λ, the following scenarios are true:</b>
#
# ![poissonparameter.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/poissonparameter.PNG)

# %% [markdown]
# ### <b> Real-World Problem:</b>
#
# The number of spares required for any component in a machine follows a Poisson distribution with λ = 2.
# An enterprise using this machine must arrive at the number of spares of this component needed so that the probability
# of a stock out is at most 0.06. How can we determine this number?

# %% [markdown]
# ![poissontable.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/poissontable.PNG)

# %% [markdown]
# ![poissonexample1.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/poissonexample1.PNG)

# %% [markdown]
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Real_World_Problem.png)

# %% [markdown]
# <b> Note:</b> The stock out probability for a given value = 1 – Cumulative value
#
# As we can see that when fewer spare units are stocked, the stock out probabilities are high.
#
# When 3 spares are stocked, the stock out probability is 0.1429. The stock out probability when 4 spare parts are stocked
# is 0.0527. Since the stock out probability should not exceed 0.06, the firm should stock 4 units.
#
# The binomial can sometimes be approximated by a Poisson theorem.
#
# ![binomailas.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/binomailas.PNG)
#
#
# This is called Poisson distribution.

# %% [markdown]
# ### __Python Code to Plot the Curve for a Poisson Distribution__

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson, gaussian_kde

# Generate Poisson distributed data
data_poisson = poisson.rvs(mu=4, size=10000)

# Plot histogram
plt.hist(data_poisson, bins=30, density=True, alpha=0.5, color='green')

# Calculate the KDE
kde = gaussian_kde(data_poisson)
kde_xs = np.linspace(data_poisson.min(), data_poisson.max(), 301)
kde_ys = kde.pdf(kde_xs)

# Plot KDE
plt.plot(kde_xs, kde_ys, color='blue')

# Add labels
plt.xlabel('Poisson')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# ### __Use Case: To Determine the Probability of Restaurants__

# %% [markdown]
# #### __Problem Statement:__

# %% [markdown]
# Suppose you are going for a long drive. The rate of occurrences of good restaurants in a range of 10 miles is 2.
# In other words, the mean number of occurrences of restaurants in a range of 10 miles is 2. What is the probability
# that 0, 1, 2, 3, 4, or 5 restaurants will show up in the next 10 miles.

# %% [markdown]
# **Solution:**

# %% [markdown]
# The probability of the different number of restaurants ranging from 0 to 5 that one could find within 10 miles given
# the mean number of occurrences of the restaurant in 10 miles is 2.

# %%
# Scipy.stats poisson class is used along with PMF method to calculate the value of probabilities
from scipy.stats import poisson
import matplotlib.pyplot as plt

# Random variable representing number of restaurants
# Mean number of occurrences of restaurants in 10 miles is 2
X = [0, 1, 2, 3, 4, 5]
lmbda = 2

# Probability values
poisson_pd = poisson.pmf(X, lmbda)

# Plot the probability distribution
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
ax.plot(X, poisson_pd, 'bo', ms=8, label='poisson pmf')
plt.ylabel("Probability", fontsize="18")
plt.xlabel("X = No. of restaurants", fontsize="18")
plt.title("Poisson distribution - No. of restaurants vs probability", fontsize="18")
ax.vlines(X, 0, poisson_pd, colors='b', lw=5, alpha=0.5)

# %% [markdown]
# As we can see, the Poisson probability distribution X indicates the number of Restaurants in 10 miles.

# %% [markdown]
# ## __8. Continuous Probability Distribution__
#
# Two types of continuous probability distribution:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Continuous_Probability_Distribution.png)

# %% [markdown]
# ## __9. Normal Distribution__

# %% [markdown]
# Normal distribution extends between -∞ to +∞ (minus infinity to plus infinity). The distribution is completely
# specified by its mean μ and standard deviation σ. The value of population mean μ can be positive, negative, or zero.
#
# ![meanvale.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/meanvale.PNG)

# %% [markdown]
# The properties of the normal distribution are:
#
#
#  ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/The_properties_of_the_normal_distribution_are.png)
#
#
#
#
#
# ### __9.1 Standard Normal Distribution__
#
# The normal distribution with mean 0 and standard deviation 1 is called the standard normal distribution.

# %% [markdown]
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/9_1_Standard_Normal_Distribution.png)

# %% [markdown]
# Statistical tables are used to get probabilities for Z, that is, the normal distribution with zero mean and
# standard deviation unity. For other values of mean and standard deviation, probabilities are obtained using
# the transformation.
#
#                                                   Z= (X – μ)/ σ

# %% [markdown]
# ### __Example:__

# %% [markdown]
# A factory outlet uses a filling machine for low-pressure oxygen shells. It has been established that the weights of
# filled cylinders in grams follow a normal distribution with population mean μ = 1.433 and
# standard deviation σ = 0.033. The specification limits are 1.460± 0.085.
#
# <b>How can we determine the probability that a cylinder will meet the specifications?</b>

# %% [markdown]
# <b>Solution:</b> Let the random variable X denote the weight of a filled cylinder (grams).
#
# ![specificationlimits.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/specificationlimits.PNG)

# %% [markdown]
# Calculate the probability that X falls within the specification limits of 1.375, 1.545 grams.
# - For this, calculate the Z-scores for the lower and upper specification limits:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/For_this_calculate.png)

# %% [markdown]
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Calculate_the_probability.png)

# %% [markdown]
# ### __Python Code to Plot the Curve for a Normal Distribution__

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, gaussian_kde

# Generate normally distributed data
mu = 0      # Mean
sigma = 1   # Standard deviation
data_normal = norm.rvs(mu, sigma, size=10000)

# Plot histogram
plt.hist(data_normal, bins=30, density=True, alpha=0.5, color='blue')

# Calculate the KDE
kde = gaussian_kde(data_normal)
kde_xs = np.linspace(data_normal.min(), data_normal.max(), 301)
kde_ys = kde.pdf(kde_xs)

# Plot KDE
plt.plot(kde_xs, kde_ys, color='red')

# Add labels
plt.xlabel('Normal distribution')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# ## __10. Uniform Distribution__

# %% [markdown]
# It is a probability distribution where all values in a given range are equally likely to occur, resulting in a rectangular-shaped probability density function.
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Uniform_Distribution.png)

# %% [markdown]
# A random variable X follows a uniform distribution in the range [a, b], if the probability of lying in the range [c, d] is directly proportional to the length of the interval.
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/A_random_variable_X.png)
#
#
# - The values a, b, c, and d are all finite, but they can be positive, negative, or zero.

# %% [markdown]
# ### __Example:__

# %% [markdown]
# Suppose a bus arrives at a stop every 20 minutes. What is the probability that the bus will arrive in 8 minutes or less
# if you arrive at the bus stop?

# %%
from scipy.stats import uniform

# Calculate uniform probability
uniform.cdf(x=8, loc=0, scale=20) - uniform.cdf(x=0, loc=0, scale=20)
# Out:
# 0.4

# %% [markdown]
# The probability that the bus arrives in 8 minutes or less is 0.4.

# %% [markdown]
# ### __Python Code to Plot the Curve for a Uniform Distribution__

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import uniform

# Generate uniformly distributed data
a, b = 0, 10  # Define the start and end points of the uniform distribution
data_uniform = uniform.rvs(a, b-a, size=10000)

# Plot histogram
plt.hist(data_uniform, bins=30, density=True, alpha=0.5, color='blue')

# Calculate the PDF of the Uniform Distribution
uniform_xs = np.linspace(a, b, 301)
uniform_ys = uniform.pdf(uniform_xs, a, b-a)

# Plot PDF
plt.plot(uniform_xs, uniform_ys, color='red')

# Add labels
plt.xlabel('Uniform Distribution')
plt.ylabel('Density')

# Display the plot
plt.show()

# %% [markdown]
# ## __11. Probability Density Function and Mass Function__

# %% [markdown]
# The probability density function is used to specify the probability that the random variable falls
# within a range of values as opposed to taking on one particular value.
#
# Since there are infinite possible values for a continuous random variable, the absolute likelihood that it will take up a particular value is 0.
#
# But if we take two samples, we can determine how likely it is to fall in one sample compared to the other.
#
# The probability is given by the integral of the probability density function over that range. It is the area
# under the density function above the horizontal axis between the lowest and highest values of that range.
#
# The probability density function is non-negative everywhere and its integral over the entire space is equal to 1.
#
# But when the random variables take only discrete values, the same function is called probability mass function.
#
# So formally, for a continuous random variable X with probability density function f(x):
#
# ![probmassfunction.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/probmassfunction.PNG)
#
#
# <center>So, f(x) $\geq$ 0 for all x.</center>

# %% [markdown]
# The area under the density curve and above the horizontal axis over the entire space is equal to 1. So,
#
# ![pmfequation.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/pmfequation.PNG)

# %% [markdown]
#
# #### <b>Example:</b>
#
# If X is a continuous random variable with the following density function:
#
# ![pmseq.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/pmseq.PNG)
#
#
#
# To calculate P(1 < X < 2) per definition
#
#
#
# P(1<X<2) =  $ \int_{1}^2 {x^2}/9  dx $ = $ \left[\frac{x^3}{27}\right]_{1}^{2} = \frac{2^3}{27} - \frac{1^3}{27} $ = 7/27

# %% [markdown]
# ## __12. Cumulative Distribution Function__

# %% [markdown]
# Probability mass function can’t be defined for continuous random variables, cumulative distribution function is
# used to describe their distribution. It can be used to describe:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Cumulative_Distribution_Function.png)

# %% [markdown]
# The cumulative distribution function of a real valued random variable X evaluated at x is the probability
# that X will take a value less than or equal to x.
#
#
# So formally, the cumulative distribution function of a random variable X is defined as:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Updated_Images/Lesson_7/7_01/Lesson_07_Probability_distributionSo_formally_the_cumulative.png)

# %% [markdown]
# The CDF is monotonously increasing, that is,
# if ${x_1}$ $\leq$ ${x_2}$, then ${F_x}$${(x_1)}$ $\leq$ ${F_x}$${(x_2)}$
#
#
#
# Also, the CDF of a continuous random variable can be expressed as an integral of its probability density function ${F_x}$ as follows:
#
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Also_the_CDF.png)

# %% [markdown]
# ### __12.1 CDF Properties:__

# %% [markdown]
#
# Each CDF is right-continuous and non-decreasing. Furthermore,
#
# $\lim_{x \to -\infty} F_x(x)$ = 0 and $\lim_{x \to +\infty} F_x(x)$ = 1
#
# #### **Example:**
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Updated_Images/Lesson_7/7_01/Lesson_07_Probability_distribution12_1_CDF_Properties.png)

# %% [markdown]
# ## __13. Central Limit Theorem__

# %% [markdown]
# #### <b> Scenario 1:</b>
#
# Consider a math's test score of a school of 1000 students. If we test 100 of them, the results won't significantly deviate from the results of the entire student population. According to the central limit theorem, the average test result for these 100 students will typically be the same as the average test result for the population of 1000 students.
#
# Assume that the test scores of 1000 students are not available and 100 students are tested. The average test score of these 100 students reflects the population mean.
#
# The central limit theorem helps calculate the probability that a particular sample was drawn from a given population. If the probability is low, it can be concluded that the sample isn’t from that population or it isn’t a representative of that population and needs to be collected again.

# %% [markdown]
# #### <b> Scenario 2</b>
#
# Consider the two given samples. We can infer whether they were likely drawn from the same population.
#
#
# The central limit theorem states that given a sufficiently large sample size from a population with a finite
# variance level, the mean of all sampled variables from the same population will be approximately equal to the
# mean of the whole population. These samples approximate a normal distribution with their variances being approximately
# equal to the variance of the population, as the sample size grows.
#
# This theorem states that if $ {X_1}, {X_2}, {X_3}.....,{X_n} $ are independent random variables that are
# identically distributed and have finite mean $\mu$ and variance $\sigma^2$
#
# then, if ${S_n} = {X_1}+{X_2}+ {X_3}+......+ {X_n}$ (n approaches infinity),
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/then_if_SnX1X2X3Xn_n_12.png)
#
#
#
# That is, the random variable  $({S_n} - n\mu )$/$\sigma$$\sqrt{n}$ , which is the standardized variable corresponding
# to ${S_n}$ is asymptotically normal.
#
# The theorem is also true under more general conditions.
#
# For example:
#
# When ${X_1, X_2, X_3,......, X_n}$ are independent random variables with the same mean and the same variance but not necessarily identically distributed.

# %% [markdown]
# ## __14. Bayes’ Theorem__

# %% [markdown]
# Bayes’ theorem describes how the conditional probability of each of a set of possible causes for a given observed
# outcome is computed by knowing the probability of each cause and the conditional probability of the outcome of each cause.
#
# Bayes’ theorem can be expressed as a mathematical equation and used to calculate the probability of one event based on
# its connection with another event. It is also known as Bayes' law or Bayes' rule.

# %% [markdown]
# ### __14.1 Applications of Bayes’ Theorem__

# %% [markdown]
# Mathematically, Bayes’ theorem is expressed as:

# %% [markdown]
# ![Bayes.png](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Bayes.png)

# %% [markdown]
# Where, A and B are events
#
# P(A|B) is the probability of A happening in case B happens.
#
# P(B|A) is the probability of B happening in case A happens.
#
# P(A) is the independent probability of A.
#
# P(B) is the independent probability of B.

# %% [markdown]
# ### __Example to Illustrate How Bayes’ Theorem Tries to Predict One Event in Case the Other Is True:__

# %% [markdown]
# Rainy days bring us showers and lightning. Sometimes, there are showers with lightning, and sometimes showers without
# lightning. Similarly, sometimes there is lightning, but no showers. The Bayes’ theorem helps us find how often there is
# lightning, when there are showers. The solution is expressed as: P(Lightning | Shower).
#
#
# P(Lightning|Shower) = P(Shower|Lightning) x P(Lightning) / P(Shower)
#
# Here, P(Lightning) is the probability of lightning, and P(Shower) is the probability of showers.
#
# P(Shower|Lightning) is the probability of showers when there is lightning.
#
# It is required to know P(Shower|Lightning), which is the probability of showers when there is lightning. This is
# referred to as ‘backward’ of what we want to predict, while what we want to predict is ‘forward’. Therefore, the
# formula predicts the 'forward' event P(Lightning|Shower) by knowing the 'backward' event, which is P(Shower|Lightning).
#
# The problem is seasonal, and the various events are related. The Bayes’ theorem helps us predict one when the other is
# known.

# %% [markdown]
# ## __15. Estimation Theory__

# %% [markdown]
# Estimation theory is the science of guessing or estimating the properties of a population from which data is collected. The guesswork happens by determining the approximate value of a population parameter based on a sample statistic.
#
#
# The estimator is a rule or formula that can be used to calculate the estimate based on the sample.
#
# ![estimation.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/estimation.PNG)
#
# <b> Good estimators: </b>
#
# 1) Good estimators are unbiased, that is, the average value of the estimator equals the parameter to be estimated.
#
# 2) It also has minimum variance, that is, among all the unbiased estimators, the best one has a sampling
#    distribution with the smallest standard error.
#
# Two kinds of estimators are:
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/Good_estimators.png)

# %% [markdown]
# ### __15.1 What Is Point Estimator?__

# %% [markdown]
# 1. Point estimators are functions that are used to estimate the value of a population parameter using random samples of the population.
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_07_Probability_distribution/What_Is_Point_Estimator.png)
#
#
# **Note:** Point estimates are never perfect and they always have an error component (margin of error).
#
# 2. A point estimator is assessed on three criteria:
#
# ![point.PNG](https://s3.us-east-1.amazonaws.com/static2.simplilearn.com/lms/testpaper_images/ADSP/Advanced_Statistics/Probimages/point.PNG)

# %% [markdown]
# * <b>Unbiasedness (mean):</b> It is a measurement of whether the mean of this estimator is close to the actual parameter.
#
#
# * <b> Efficiency (variance):</b> It denotes whether the standard deviation of this estimator is close to the actual parameter.
#
#
# * <b> Consistency (size):</b> It indicates whether the probability distribution of the estimator is concentrated on the
# parameter with an increase in the sample size.

# %% [markdown]
# ### __Use Case: Finding a Point Estimate__

# %% [markdown]
# #### __Problem Statement:__
#
# An economics researcher is collecting data about grocery store employees in a country. The data represents a random sample of the number of hours worked by 40 employees from several grocery stores in the country. Find a point estimate of the population mean.

# %% [markdown]
# #### __Solution:__

# %%
# Random data of forty employees
data = [30, 26, 33, 26, 26, 33, 31, 31, 21, 37,
        27, 20, 34, 35, 30, 24, 38, 34, 39, 31,
        22, 30, 23, 23, 31, 44, 31, 33, 33, 26,
        27, 28, 25, 35, 23, 32, 29, 31, 25, 27]

n = len(data)
sample_mean =  sum(data) / n
print('sample mean: ', sample_mean)
# Out:
# sample mean:  29.6

# %% [markdown]
# So, the point estimate for the mean number of hours worked by grocery store employees in this country is 29.6 hours.

# %% [markdown]
# ### __15.2 Interval Estimator__

# %% [markdown]
# An interval estimator of a population parameter under random sampling consists of two random variables, called
# the upper and lower limits, whose values decide intervals that expect to contain the parameter estimated.
#
# * Interval estimates are all the ranges that an interval estimator can assume.
#
#
# * There is a range within which a population parameter probably lies, and the interval estimate captures that.
#
#
# **Example:** The mean income of a class of graduate trainees is
# between (775-950) dollars per week.
#
#
# An interval estimator can be assessed through its:
#
# 1) Accuracy or confidence level
#
# 2) Precision or margin of error
#
# The design of an interval estimator consists of evaluating an unbiased point estimator and designating an interval
# of logical width around it.

# %% [markdown]
# ## __Assisted Practice__

# %% [markdown]
# ### **Problem Statement:**
#
# Utilize various probability distributions to analyze customer behaviors and store performance metrics using a custom dataset.
#
# __Dataset Name:__ Retail_Store_Data.csv (download it from reference material section in LMS)
#
# Variables:
# - `Customer_ID:` Unique identifier for each customer
# - `Purchase_Amount:` Amount spent by a customer in a single visit (in dollars)
# - `Visit_Duration:` Time spent by the customer in the store (in minutes)
# - `Items_Purchased:` Number of items purchased in a single visit
# - `Store_Section:` Section of the store where the customer spent the most time (For example, electronics, apparel, groceries)
# - `Weekday:` Day of the week when the visit occurred

# %% [markdown]
# __Steps to Perform:__
#
# - Data Preparation:
#   * Import necessary Python libraries (for example, Pandas, NumPy, Matplotlib, SciPy)
#   * Load the "Retail_Store_Data.csv" dataset
#   * Perform basic data exploration (for example, view the first few rows, check for null values)
#
# - Bernoulli Distribution:
#   * Create a binary variable representing whether a customer spent more than 30 minutes in the store (1 for Yes, 0 for No).
#   * Analyze this variable using Bernoulli distribution
#
# - Binomial Distribution:
#   * Consider 10 random visits; analyze the number of visits where customers spent over $100 using the binomial distribution
#
# - Poisson Distribution:
#   * Analyze the number of customers visiting the store per hour. Assume the store's data indicates an average of 15 customers per hour
#
# - Normal Distribution:
#   * Examine the Purchase_Amount variable. Check if it follows a normal distribution. Calculate its mean and standard deviation.
#
# - Uniform Distribution:
#   * Analyze the Visit_Duration variable under the assumption that all time intervals are equally likely within the store’s opening hours

# %% [markdown]
# ## **Assisted Practice — Solution Walkthrough**
#
# Step 0: Load data + quick inspection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import bernoulli, binom, poisson, norm, uniform

df = pd.read_csv("Retail_Store_Data.csv")

df.head()
df.describe(include="all")
# Out:
#         Customer_ID  Purchase_Amount  Visit_Duration  Items_Purchased  \
# count   1000.000000      1000.000000     1000.000000      1000.000000
# unique          NaN              NaN             NaN              NaN
# top             NaN              NaN             NaN              NaN
# freq            NaN              NaN             NaN              NaN
# mean     500.500000       150.966603       65.401369         4.929000
# std      288.819436        48.960797       31.719252         2.096749
# min        1.000000       -12.063367       10.354009         0.000000
# 25%      250.750000       117.620485       37.191903         3.000000
# 50%      500.500000       151.265031       66.773863         5.000000
# 75%      750.250000       182.397194       92.095050         6.000000
# max     1000.000000       342.636575      119.935510        12.000000
#
#        Store_Section Weekday
# count           1000    1000
# unique             3       7
# top        Groceries  Friday
# ...

# %% [markdown]
# ## **A) Bernoulli Distribution**
#
# Task: Create a binary variable: spent > 30 minutes (1 yes, 0 no), analyze with Bernoulli.

# %%
df["Spent_Over_30"] = (df["Visit_Duration"] > 30).astype(int)

p_hat = df["Spent_Over_30"].mean()   # estimated probability of success
p_hat
# Out:
# np.float64(0.813)

# %% [markdown]
# *  We encoded success as ‘spent over 30 minutes’.
#
#
# *  The sample mean of a 0/1 variable equals the proportion of 1s, which is our estimated p.
#
# Optional visualization:

# %%
df["Spent_Over_30"].value_counts(normalize=True).plot(kind="bar")
plt.title("Bernoulli Outcome: Spent Over 30 Minutes")
plt.show()

# %% [markdown]
# ## **B) Binomial Distribution**
#
# Task: Consider 10 random visits; analyze number of visits where Purchase_Amount > 100.

# %%
df["Over_100"] = (df["Purchase_Amount"] > 100).astype(int)
p_over100 = df["Over_100"].mean()

n = 10
r_values = np.arange(0, n+1)
pmf_vals = binom.pmf(r_values, n=n, p=p_over100)

pmf_vals
# Out:
# array([4.71165353e-09, 2.73404113e-07, 7.13919516e-06, 1.10471355e-04,
#        1.12181031e-03, 7.81146283e-03, 3.77731167e-02, 1.25249635e-01,
#        2.72545762e-01, 3.51446009e-01, 2.03934317e-01])

# %% [markdown]
# *  Each visit is a Bernoulli trial: success = spent over $100.
#
#
# *  Ten visits becomes binomial with parameters n=10, p=estimated proportion over $100.
#
#
# *  PMF gives probability of exactly r successes.
#
# Plot:

# %%
plt.stem(r_values, pmf_vals)
plt.title("Binomial PMF: # of >$100 Purchases in 10 Visits")
plt.xlabel("r successes")
plt.ylabel("Probability")
plt.show()

# %%
# P(X >= 4) = 1 - P(X <= 3)
p_ge_4 = 1 - binom.cdf(3, n=n, p=p_over100)
p_ge_4
# Out:
# np.float64(0.999882111333603)

# %% [markdown]
# ## **C) Poisson Distribution**
#
# Task: Average 15 customers per hour; analyze counts per hour.

# %%
lam = 15
k = np.arange(0, 40)
pmf_k = poisson.pmf(k, mu=lam)

plt.stem(k, pmf_k)
plt.title("Poisson PMF: Customers per Hour (λ=15)")
plt.xlabel("k customers")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# λ is the expected rate—this is exactly the Lesson 07 knowledge check: λ represents the expected number of occurrences.
#
# Example probability:

# %%
poisson.pmf(20, mu=lam)   # P(X=20)
# Out:
# np.float64(0.04181030500106466)

# %% [markdown]
# ## **D) Normal Distribution**
#
# Task: Examine Purchase_Amount, check if it roughly follows normal; compute mean and std.

# %%
mu = df["Purchase_Amount"].mean()
sigma = df["Purchase_Amount"].std(ddof=1)

mu, sigma
# Out:
# (np.float64(150.9666027911163), 48.96079690898381)

# %% [markdown]
# Visual check:

# %%
plt.hist(df["Purchase_Amount"], bins=30, density=True, alpha=0.5)
xs = np.linspace(df["Purchase_Amount"].min(), df["Purchase_Amount"].max(), 300)
plt.plot(xs, norm.pdf(xs, loc=mu, scale=sigma))
plt.title("Purchase Amount: Histogram + Normal Curve Overlay")
plt.show()

# %% [markdown]
# *  We’re not proving normality—just checking whether a normal model is reasonable.
#
#
# *  This matters next session because Z/T methods assume sampling distributions that are normal-ish.

# %% [markdown]
# ## **E) Uniform Distribution**
#
# Task: Analyze Visit_Duration assuming equal likelihood across an interval (a, b)
#
# A simple approach:

# %%
a = df["Visit_Duration"].min()
b = df["Visit_Duration"].max()

# Uniform over [a, b]
xs = np.linspace(a, b, 300)
pdf = uniform.pdf(xs, loc=a, scale=(b-a))

plt.hist(df["Visit_Duration"], bins=30, density=True, alpha=0.5)
plt.plot(xs, pdf)
plt.title("Visit Duration: Histogram + Uniform PDF (Assumption Check)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = df["Visit_Duration"].min()
#       2 b = df["Visit_Duration"].max()
#       4 # Uniform over [a, b]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Uniform is often an assumption model. If the histogram is nowhere near flat, uniform isn’t a great fit—this becomes a modeling decision, not just a math step.
